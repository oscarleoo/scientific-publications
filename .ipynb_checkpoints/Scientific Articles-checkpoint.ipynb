# %%
import imageio

import numpy as np
import pandas as pd
import geopandas as gpd

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from PIL import Image
from matplotlib.ticker import FuncFormatter
from matplotlib.colors import LinearSegmentedColormap, ListedColormap

# %% [markdown]
# ## Helper Functions

# %%
def set_seaborn_style(font_family, background_color, grid_color, text_color):
    sns.set_style({
        "axes.facecolor": background_color,
        "figure.facecolor": background_color,
        "axes.edgecolor": grid_color,
        "axes.grid": True,
        "axes.axisbelow": True,
        "grid.color": grid_color,
        "text.color": text_color,
        "font.family": font_family,
        
        "xtick.color": text_color,
        "ytick.color": text_color,
        "xtick.bottom": False,
        "xtick.top": False,
        "ytick.left": False,
        "ytick.right": False,

        "axes.spines.left": False,
        "axes.spines.bottom": True,
        "axes.spines.right": False,
        "axes.spines.top": False,
    }
)
    
def add_padding_to_chart(chart, left, top, right, bottom, background):
    size = chart.size
    image = Image.new("RGB", (size[0] + left + right, size[1] + top + bottom), background)
    image.paste(chart, (left, top))
    return image

# %% [markdown]
# ## About the Data
#
# The data measure the number of scientific articles published in a set of journals. If an article have multiple authors that comes from different countries each country get a fraction. We have data from 1996 to 2020 for every country in the world.

# %%
df = pd.read_csv("./data/scientific.csv", index_col=None)
population = pd.read_csv("./data/population.csv", index_col=None)

df = df.sort_values("country_name")
population = population.sort_values("country_name")

# %%
years = list(population.columns[1:])
population.iloc[:, 1:] = df[years] * (100000 / population[years])

df = df.sort_values("2020", ascending=False)
population = population.sort_values("2020", ascending=False)

# %%
df = df.sort_values("2020", ascending=False)
population = population.sort_values("2020", ascending=False)

# %% [markdown]
# ## Charts

# %%
font_family = "PT Mono"
background_color = "#FAE8E0"
text_color = "#040F0F"
grid_color = "#DDC9A7"

set_seaborn_style(font_family, background_color, grid_color, text_color)

# %%
def add_padding_to_chart(chart, left, top, right, bottom, background):
    size = chart.size
    image = Image.new("RGB", (size[0] + left + right, size[1] + top + bottom), background)
    image.paste(chart, (left, top))
    return image

# %%
population
# Out:
#           country_name        1996        1997        1998        1999
# 167        Switzerland  162.602572  167.557025  168.577473  167.475015  \
# 46             Denmark  120.847626  134.480645  128.626288  126.230622
# 128             Norway  109.328296  117.094578  117.506991  107.408863
# 8            Australia  114.131775  117.937775  118.131725  118.045335
# 151          Singapore   66.472807   83.478880   81.770711  102.055890
# ..                 ...         ...         ...         ...         ...
# 4               Angola    0.041367    0.049290    0.026746    0.024763
# 158        South Sudan    0.000000    0.000000    0.000000    0.000000
# 53   Equatorial Guinea    0.142471    0.209720    0.000000    0.334336
# 178       Turkmenistan    0.239474    0.173707    0.127947    0.039324
# 33                Chad    0.014027    0.043619    0.019457    0.044852
#
#            2000        2001        2002        2003        2004  ...
# 167  175.681943  170.095551  171.300935  179.359425  191.833956  ...  \
# 46   134.483641  133.581263  133.748554  138.828444  145.807872  ...
# 128  112.743425  114.301165  113.900593  116.058670  125.747020  ...
# 8    123.475666  124.359646  125.683745  130.093110  139.652728  ...
# 151  119.480512  118.826625  131.577006  149.073861  179.045395  ...
# ..          ...         ...         ...         ...         ...  ...
# 4      0.037087    0.056547    0.092087    0.032498    0.051835  ...
# 158    0.000000    0.000000    0.000000    0.000000    0.000000  ...
#
# 103   21280.39   21884.84   26.334183
# 21      767.50     932.51   27.113054
# 19       53.63      79.66   31.382114
# 142     189.37     263.99   32.501269
# 29      140.82     166.15   32.633603
# 28       13.25      21.50   39.566038
# 189    5812.63    8213.16   45.037892
# 50     2308.59    2847.83   49.155513
# 139    1785.11    2346.63   50.551626
# 118     281.53     418.50   72.421053
# 78    52885.10   57755.27   87.943205
# 77    30446.15   32553.79  106.070747
# 79     6776.40    9814.39  133.591196
# 161      33.88      33.69  133.760000
# 89      146.09     176.64  152.600000
# 0       133.29     119.74  920.076923
# 172      14.09      11.87         inf
# 148    4939.18    4741.34         inf
# 174       2.62       9.24         inf
# 120       0.33       0.90         inf
# 158       8.92      14.27         inf
# 115     278.72     309.32         inf
# 5         5.97       7.29         inf
# 179       0.12       0.39         inf
#
# [50 rows x 27 columns]

# %%
fig = plt.figure(figsize=(16, 18))

ax = sns.barplot(y=population.country_name[:20], x=population["2020"][:20], color="#99D6C2", orient="h")

ax.set(xlabel=None, ylabel=None)
ax.tick_params("y", labelsize=20, pad=8)
ax.tick_params("x", labelsize=20, pad=16)
ax.get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))

plt.title("Number of Scientific Articles in 2020", fontsize=32, y=1.06, x=0.48)
plt.tight_layout()

fig.canvas.draw()
data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
data = data.reshape((fig.canvas.get_width_height()[::-1]) + (3,))
plt.close() 
# plt.show()

chart_image = Image.fromarray(data)
chart_image = add_padding_to_chart(chart_image, 30, 50, 100, 30, background_color)
chart_image
# Out:
# <PIL.Image.Image image mode=RGB size=1730x1880>

# %%
from matplotlib.patches import Patch

# %%
fig = plt.figure(figsize=(16, 9))

ax = sns.lineplot(
    y = df[df.country_name == "China"].iloc[-1][4:],
    x = list(df.columns[4:].astype(int)),
    color="#EF7C8E", linewidth=6, marker="o", markers=True
)


ax = sns.lineplot(
    y = df[df.country_name == "United States"].iloc[-1][4:],
    x = list(df.columns[4:].astype(int)),
    color="#85A5EA", linewidth=6, marker="o", markers=True
)

ax.set(xlabel="", ylabel="")
ax.tick_params("y", labelsize=20, pad=8)
ax.tick_params("x", labelsize=20, pad=16)
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))

b_patch = Patch(color='#85A5EA', label='United States', linewidth=2)
r_patch = Patch(color='#EF7C8E', label='China')
leg = plt.legend(
    handles=[b_patch, r_patch],
    bbox_to_anchor=(0.48, 1.09), loc='lower center',
    borderaxespad=0, ncol=3, fontsize=22,
    edgecolor=background_color
)

plt.ylim(0, None)
plt.title("Number of Scientific Publications Over Time", fontsize=32, y=1.22, x=0.48)
plt.tight_layout()

fig.canvas.draw()
data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
data = data.reshape((fig.canvas.get_width_height()[::-1]) + (3,))
plt.close() 
# plt.show()

chart_image = Image.fromarray(data)
chart_image = add_padding_to_chart(chart_image, 30, 20, 30, 30, background_color)
chart_image
# Out:
# <PIL.Image.Image image mode=RGB size=1660x950>
